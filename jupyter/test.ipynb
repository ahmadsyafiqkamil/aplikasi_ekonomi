# %%
import os
from dotenv import load_dotenv
load_dotenv()

news_keys = os.getenv('NEWS_KEY')
fred_keys = os.getenv('FRED_API_KEY')

# %%
fred_keys
# Out:
# '500a605c76caccf418b1f6d88f831f52'

# %%
from newsapi import NewsApiClient

api = NewsApiClient(api_key=news_keys)
api.get_everything(q='oil')
# Out:
# {'status': 'ok',
#  'totalResults': 39575,
#  'articles': [{'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Claire Lower',
#    'title': "Please Don't Put Cooking Spray in Your Air Fryer",
#    'description': 'One of things everyone loves about their air fryer is how it can make foods crispy without using a ton of oil. This does not, however, prevent people from adding some oil to their food. After all, fat is flavor, and there can be some anxiety over things stick…',
#    'url': 'https://lifehacker.com/please-dont-put-cooking-spray-in-your-air-fryer-1849626915',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/2923b66a2d791c36233dee768e569b32.jpg',
#    'publishedAt': '2022-10-07T12:00:00Z',
#    'content': 'One of things everyone loves about their air fryer is how it can make foods crispy without using a ton of oil. This does not, however, prevent people from adding some oil to their food. After all, fa… [+1776 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': None,
#    'title': 'The complex process for tasting olive oil',
#    'description': 'The Puglia region of Italy is famous for its fragrant olive oil. Stanely Tucci visited a Puglian olive farm and learned the proper technique for tasting. "Searching for Italy" airs Sundays at 9 p.m. ET.',
#    'url': 'https://www.cnn.com/videos/travel/2022/10/12/olive-oil-tasting-stanley-tucci-searching-for-italy-origseriesfilms.cnn',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/221012192638-olive-oil-tasting-stanley-tucci-searching-for-italy-origseriesfilms-00000911-super-tease.png',
#    'publishedAt': '2022-10-20T10:45:14Z',
#    'content': "'Stanley Tucci: Searching for Italy'"},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Molly Taft',
#    'title': 'Biden to Release More Oil From U.S. Stockpile Held in Salt Caves',
#    'description': 'On Wednesday, the Biden administration announced that it would pull an additional 15 million barrels of oil out of the nation’s Strategic Petroleum Reserve (SPR) to help juice up oil supplies and keep gas prices low in the face of the global energy crisis.Rea…',
#    'url': 'https://gizmodo.com/biden-strategic-petroleum-reserve-release-1849677052',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/9f643a1700d7e8559c8ae39226973342.jpg',
#    'publishedAt': '2022-10-19T19:25:42Z',
#    'content': 'On Wednesday, the Biden administration announced that it would pull an additional 15 million barrels of oil out of the nations Strategic Petroleum Reserve (SPR) to help juice up oil supplies and keep… [+2804 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'French oil workers vote to continue strike',
#    'description': 'The stoppage at refineries, now in its third week, has led to long queues at petrol stations.',
#    'url': 'https://www.bbc.co.uk/news/world-europe-63225948',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/6D02/production/_127060972_tv079435858.jpg',
#    'publishedAt': '2022-10-12T09:45:39Z',
#    'content': 'Striking French oil workers have voted to continue their industrial action, which has led to shortages at fuel stations across the country. \r\nThey responded angrily after the government said it would… [+1814 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Claire Lower',
#    'title': 'How to Keep Leftover Pesto Looking Fresh and Green',
#    'description': 'Pesto, made with pine nuts and Italian cheese, is not a cheap sauce, mainly because of those pine nuts. It makes sense then, that one should want their pesto to look as good as it tastes, even if it’s been sitting in the fridge for a few days. The problem, th…',
#    'url': 'https://lifehacker.com/how-to-keep-leftover-pesto-looking-fresh-and-green-1849616498',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/9dc72ca97f9c1646d5c1c7834e104702.jpg',
#    'publishedAt': '2022-10-05T13:00:00Z',
#    'content': 'Pesto, made with pine nuts and Italian cheese, is not a cheap sauce, mainly because of those pine nuts. It makes sense then, that one should want their pesto to look as good as it tastes, even if its… [+1646 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': None,
#    'title': 'In Italy, Tucci drinks a wine glass of olive oil',
#    'description': 'In Liguria, Stanley Tucci samples olive oils. He describes it as fruity and creamy. "Stanley Tucci: Searching for Italy" airs this Sunday at 9 p.m. ET.',
#    'url': 'https://www.cnn.com/videos/travel/2022/10/21/liguria-stanley-tucci-searching-for-italy-olives-origseriesfilms.cnn',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/221021135514-liguria-stanley-tucci-searching-for-italy-olives-origseriesfilms-00002407-super-tease.png',
#    'publishedAt': '2022-10-28T15:23:07Z',
#    'content': "'Stanley Tucci: Searching for Italy'"},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': None,
#    'title': 'British Cycling: Open letter calling for end to Shell deal receives more than 700 signatures',
#    'description': 'More than 700 organisations and individuals sign an open letter to British Cycling calling for it to "renounce" its sponsorship deal with oil giant Shell.',
#    'url': 'https://www.bbc.co.uk/sport/cycling/63218485',
#    'urlToImage': 'https://ichef.bbci.co.uk/live-experience/cps/624/cpsprodpb/4465/production/_124090571_cycling_getty.jpg',
#    'publishedAt': '2022-10-11T16:23:13Z',
#    'content': 'British Cycling has signed an eight-year deal with Shell\r\nMore than 700 organisations and individuals have signed an open letter to British Cycling calling for the governing body to "renounce" its sp… [+2065 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Peru: Tourists detained on river boat in oil protests',
#    'description': 'Around 70 tourists, including some from the UK, were on a boat stopped by an indigenous group.',
#    'url': 'https://www.bbc.co.uk/news/world-latin-america-63511143',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/E6E8/production/_127521195_mediaitem127521192.jpg',
#    'publishedAt': '2022-11-04T15:52:11Z',
#    'content': 'Seventy tourists on a river boat in Peru have been detained by an indigenous group as part of a protest against a recent oil spill.\r\nThe UK Foreign Office says a "very small number" of British nation… [+1561 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Lindsey Ellefson',
#    'title': 'Easy Ways to Make Your Laundry Smell Good (Without Harsh Detergents)',
#    'description': 'When you have especially stinky clothes, washing and deodorizing them is the bare minimum you ask of your washing machine. That’s why we’ve shared so many tips over the years on how to go about it the right way. But what about when you just want your clothes …',
#    'url': 'https://lifehacker.com/easy-ways-to-make-your-laundry-smell-good-without-hars-1849733422',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/fe85a03b6e715c727b61f5766cddced8.jpg',
#    'publishedAt': '2022-11-02T20:00:00Z',
#    'content': 'When you have especially stinky clothes, washing and deodorizing them is the bare minimum you ask of your washing machine. Thats why weve sharedso many tips over the years on how to go about it the r… [+2319 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Telangana’s ambitious palm oil strategy to help India reduce import',
#    'description': 'The Telangana state government is investing heavily in the crop, but experts remain sceptical.',
#    'url': 'https://www.bbc.co.uk/news/world-asia-india-63212557',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/C216/production/_127268694_oilpalm.png',
#    'publishedAt': '2022-10-30T22:52:04Z',
#    'content': 'An 80km (49.7mile) road in Khammam district of the southern Indian state of Telangana is dotted with palm oil plantations on both sides. \r\nNagarjuna is among several farmers here who have been planti… [+7066 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Kate Knibbs',
#    'title': 'What the Soup-Throwing Climate Activists Got Right',
#    'description': 'Plus: Pipeline vandals, ketchup on hot dogs, and a billion missing crabs.',
#    'url': 'https://www.wired.com/story/what-the-soup-throwing-climate-activists-got-right/',
#    'urlToImage': 'https://media.wired.com/photos/6351df1af1f6a083059bc074/191:100/w_1280,c_limit/Soup-Throwing-Climate-Protest-Van-Gogh-Business-1243956348.jpg',
#    'publishedAt': '2022-10-21T13:00:00Z',
#    'content': 'Some people have argued that the stunt discredited the wider climate movement. I dont buy that for a second. Instead, I suspect it is far more likely to produce a helpful radical flank effect, making… [+4300 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Runaway oil - Reuters',
#    'description': 'A look at the day ahead in European and global markets from Anshuman Daga',
#    'url': 'https://www.reuters.com/markets/europe/global-markets-view-europe-2022-10-06/',
#    'urlToImage': 'https://www.reuters.com/resizer/pGJX1nKNdECZMw7OqF3vnhUa89Q=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/I7J2V4ICY5J5TLXFKETAKS6HCI.jpg',
#    'publishedAt': '2022-10-06T05:05:00Z',
#    'content': 'A look at the day ahead in European and global markets from Anshuman Daga\r\nJust when stock markets seemed to be regaining their footing after a wild third quarter - beset by rising interest rates and… [+2543 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'EXCLUSIVE Rosneft moves into tanker chartering as EU ban looms - Reuters',
#    'description': "Russia's biggest oil exporter Rosneft has expanded its tanker chartering business to ease oil shipments for buyers amid looming Western sanctions on insurance of Russian oil shipments, three sources familiar with the matter said.",
#    'url': 'https://www.reuters.com/business/energy/exclusive-rosneft-moves-into-tanker-chartering-eu-ban-looms-2022-10-17/',
#    'urlToImage': 'https://www.reuters.com/resizer/cYGKPDOC3EB6qzfnivvKkWwjNWs=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/M7C33BOWEBIKXCK757TLLQH7TI.jpg',
#    'publishedAt': '2022-10-17T14:50:00Z',
#    'content': "MOSCOW/NEW DELHI, Oct 17 (Reuters) - Russia's biggest oil exporter Rosneft has expanded its tanker chartering business to ease oil shipments for buyers amid looming Western sanctions on insurance of … [+4213 chars]"},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Claire Lower',
#    'title': 'Make a Punchy Vinaigrette With Canned Pumpkin',
#    'description': 'It’s the season when everyone tries to eat as many pumpkin- and pumpkin spice-flavored food and drinks as they can. It’s fun. It’s festive. It’s somewhat out of hand. That’s OK though. Pumpkin-mania is showing no signs of fading—at least not while Trader Joe …',
#    'url': 'https://lifehacker.com/make-a-punchy-vinaigrette-with-canned-pumpkin-1849622070',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/810410db81677c53668efd14c3cf18a4.jpg',
#    'publishedAt': '2022-10-06T14:30:00Z',
#    'content': 'Its the season when everyone tries to eat as many pumpkin- and pumpkin spice-flavored food and drinks as they can. Its fun. Its festive. Its somewhat out of hand. Thats OK though. Pumpkin-mania is sh… [+1491 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Libya NOC chief says oil output 1.2 mbpd, expects no disruption - Reuters.com',
#    'description': "The head of Libya's National Oil Corporation (NOC) said on Tuesday that oil output had risen to 1.2 million barrels per day (bpd) from 600,000 bpd three months ago and that NOC does not expect any disruption in oil production.",
#    'url': 'https://www.reuters.com/business/energy/libya-noc-chief-says-oil-output-12-mbpd-expects-no-disruption-2022-11-01/',
#    'urlToImage': 'https://www.reuters.com/resizer/GZl3EjJmXqkVQ0knvC9ZtEGd2FM=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/EDPE6KPYZVOXXGOHCNJD4TSZUQ.jpg',
#    'publishedAt': '2022-11-01T13:33:00Z',
#    'content': "ABU DHABI, Nov 1 (Reuters) - The head of Libya's National Oil Corporation (NOC) said on Tuesday that oil output had risen to 1.2 million barrels per day (bpd) from 600,000 bpd three months ago and th… [+1845 chars]"},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Stephen Johnson',
#    'title': 'The 7 Deadly Sins of Grocery Shopping',
#    'description': 'You are grocery shopping all wrong. Sadly, I can’t personally accompany you to the Piggly Wiggly and force you to navigate the supermarket correctly. I mean, I’m working on an army of atomic super-robots will be able to handle that, but until a naive venture …',
#    'url': 'https://lifehacker.com/the-7-deadly-sins-of-grocery-shopping-1849688725',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/0cc6c8583e444596790c1ea7867ba3c0.jpg',
#    'publishedAt': '2022-10-24T12:00:00Z',
#    'content': 'Most supermarkets sell cleaning supplies, school supplies, motor oil, greeting cards and all kinds of other non-food items. Its convenient, sure, but those items are usually overpriced at the grocery… [+447 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Mexico muddies waters on oil hedge to avoid cost hikes from Wall Street, oil majors - Reuters',
#    'description': 'Mexico has been requesting prices for its oil hedging program year round to make it harder for banks and oil majors, which sit on the other side of the mega deal, to hike prices, said Mexican Deputy Finance Minister Gabriel Yorio.',
#    'url': 'https://www.reuters.com/business/energy/mexico-muddies-waters-oil-hedge-avoid-cost-hikes-wall-street-oil-majors-2022-10-20/',
#    'urlToImage': 'https://www.reuters.com/resizer/UJxLqIorMA-eJn4YOfY5bYwIB8w=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/3C62HE52IBL5JHKY5YZ3UKX7QM.jpg',
#    'publishedAt': '2022-10-20T18:22:00Z',
#    'content': 'MEXICO CITY, Oct 20 (Reuters) - Mexico has been requesting prices for its oil hedging program year round to make it harder for banks and oil majors, which sit on the other side of the mega deal, to h… [+2332 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'U.S. drillers add oil and gas rigs for fourth time in five weeks - Baker Hughes - Reuters',
#    'description': 'U.S. energy firms this week added oil and natural gas rigs for the fourth time in five weeks as production growth slows despite relatively high oil prices.',
#    'url': 'https://www.reuters.com/business/energy/us-drillers-add-oil-gas-rigs-fourth-time-five-weeks-baker-hughes-2022-10-14/',
#    'urlToImage': 'https://www.reuters.com/resizer/0738l2FeTy1WZFNxrNDU7sGZ7uA=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/MFOASZOWMJI7JLLMZDFTGQJVZ4.jpg',
#    'publishedAt': '2022-10-14T17:14:00Z',
#    'content': 'Oct 14 (Reuters) - U.S. energy firms this week added oil and natural gas rigs for the fourth time in five weeks as production growth slows despite relatively high oil prices.\r\nThe oil and gas rig cou… [+1928 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Waldorf agrees to buy Korean-owned N. Sea gas producer Dana-sources - Reuters',
#    'description': 'Korea National Oil Corporation agreed to sell its North Sea oil and gas producer Dana Petroleum to private firm Waldorf Production, two industry sources told Reuters on Thursday.',
#    'url': 'https://www.reuters.com/markets/commodities/waldorf-agrees-buy-korean-owned-n-sea-gas-producer-dana-sources-2022-10-06/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=114',
#    'publishedAt': '2022-10-06T11:42:00Z',
#    'content': 'LONDON, Oct 6 (Reuters) - Korea National Oil Corporation agreed to sell its North Sea oil and gas producer Dana Petroleum to private firm Waldorf Production, two industry sources told Reuters on Thur… [+1383 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': '',
#    'title': 'Senator says Biden needs to reevaluate relations with Saudi Arabia',
#    'description': 'Sen. Chris Murphy (D-CT) discusses the US relationship and dealings with Saudi Arabia after the Saudis sided with Russia and OPEC in restricting the number of oil barrels produced by the organization.',
#    'url': 'https://www.cnn.com/videos/politics/2022/10/09/saudi-arabia-chris-murphy-russia-weapons-oil-opec-sotu-vpx.cnn',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/210217134304-biden-bin-salman-split.jpg?q=x_0,y_0,h_619,w_1100,c_fill/w_800',
#    'publishedAt': '2022-10-09T17:52:31Z',
#    'content': 'Sen. Chris Murphy (D-CT) discusses the US relationship and dealings with Saudi Arabia after the Saudis sided with Russia and OPEC in restricting the number of oil barrels produced by the organization.'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Neptune Energy in talks to sell German oil and gas assets -sources - Reuters',
#    'description': 'British oil company Neptune Energy is in advanced talks to sell its oil and gas assets in Germany to private equity firm Shorelight, industry sources told Reuters.',
#    'url': 'https://www.reuters.com/markets/deals/neptune-energy-talks-sell-german-oil-gas-assets-sources-2022-10-26/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=117',
#    'publishedAt': '2022-10-26T11:11:00Z',
#    'content': 'LONDON, Oct 26 (Reuters) - British oil company Neptune Energy is in advanced talks to sell its oil and gas assets in Germany to private equity firm Shorelight, industry sources told Reuters.\r\nThe dea… [+972 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Venezuela's October oil exports tumble on weaker production - Reuters.com",
#    'description': "Falling production knocked Venezuela's October oil exports to the fourth lowest monthly average this year, according to vessel monitoring data and documents from state-run oil firm PDVSA.",
#    'url': 'https://www.reuters.com/business/energy/venezuelas-october-oil-exports-tumble-weaker-production-2022-11-02/',
#    'urlToImage': 'https://www.reuters.com/resizer/-WPRzoN3BMybGFeTHnWGbakUIG4=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/YFJDTXRYKNMOTIQVBOQVUXSGZA.jpg',
#    'publishedAt': '2022-11-02T11:11:00Z',
#    'content': "Nov 2 (Reuters) - Falling production knocked Venezuela's October oil exports to the fourth lowest monthly average this year, according to vessel monitoring data and documents from state-run oil firm … [+2373 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Oil climbs on expectations of tight supply as Russia sanctions loom - Reuters',
#    'description': 'Oil rose in early Asian trade on Monday as expectations of tighter supplies globally ahead of European Union sanctions on Russian oil underpinned prices.',
#    'url': 'https://www.reuters.com/markets/europe/oil-climbs-expectations-tight-supply-russia-sanctions-loom-2022-10-24/',
#    'urlToImage': 'https://www.reuters.com/resizer/I88yYQ3Cx-qZAZRtUJXeuQgD5d8=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/X2VGJ2IHUNLX5EHR4VBVST4JWY.jpg',
#    'publishedAt': '2022-10-24T01:38:00Z',
#    'content': 'SINGAPORE, Oct 24 (Reuters) - Oil rose in early Asian trade on Monday as expectations of tighter supplies globally ahead of European Union sanctions on Russian oil underpinned prices.\r\nBrent crude fu… [+2230 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Nadeen Ebrahim, Abbas Al Lawati',
#    'title': "As the US-Saudi oil spat intensifies, what are Biden's options?",
#    'description': "The White House and the Democratic party are on a mission to punish the kingdom. A host of measures have been suggested, all drastic moves that analysts say could seriously dent the US' eight-decade partnership with the kingdom -- if they ever materialize.",
#    'url': 'https://www.cnn.com/2022/10/14/middleeast/us-saudi-oil-spat-options-mime-intl/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/221014113223-mime-saudi-us.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2022-10-14T15:05:41Z',
#    'content': 'Editors Note: A version of this story first appeared in CNNs Meanwhile in the Middle East newsletter, a three-times-a-week look inside the regions biggest stories. Sign up here.\r\nThe Saudi-American r… [+14690 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Rosneft's Sechin praises Saudi Arabia for 'reasonable' position on oil market - Reuters",
#    'description': 'Igor Sechin, the head of Russia\'s largest oil producer Rosneft <a href="https://www.reuters.com/companies/ROSN.MM" target="_blank">(ROSN.MM)</a>, said on Thursday that Saudi Arabia\'s position on the global oil market was "reasonable" and based on analysis of …',
#    'url': 'https://www.reuters.com/business/energy/rosnefts-sechin-praises-saudi-arabia-reasonable-position-oil-market-2022-10-27/',
#    'urlToImage': 'https://www.reuters.com/resizer/2zF2qw3MeAAe7tbWwJrf4eZp2wk=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/44P62AX5XROAZJWGDAUOGHGFH4.jpg',
#    'publishedAt': '2022-10-27T07:45:00Z',
#    'content': 'BAKU, Oct 27 (Reuters) - Igor Sechin, the head of Russia\'s largest oil producer Rosneft (ROSN.MM), said on Thursday that Saudi Arabia\'s position on the global oil market was "reasonable" and based on… [+416 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Oil prices rise on supply woes - Reuters',
#    'description': 'Oil prices rose in early Asian trade on Wednesday, paring losses from the previous session, as concern over tight supplies following reports of lower inventories in the United States offset fears of lower demand from top oil importer China.',
#    'url': 'https://www.reuters.com/business/energy/oil-prices-rise-supply-woes-2022-10-19/',
#    'urlToImage': 'https://www.reuters.com/resizer/5Pmil0p0fjd4XQZiciT9ObvJ_AA=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/72YDJCF36ZMUVCJDXWY74H6NNA.jpg',
#    'publishedAt': '2022-10-19T01:58:00Z',
#    'content': 'SINGAPORE, Oct 19 (Reuters) - Oil prices rose in early Asian trade on Wednesday, paring losses from the previous session, as concern over tight supplies following reports of lower inventories in the … [+3562 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Guyana opens tender for its first oil refinery - Reuters',
#    'description': 'Guyana has called for proposals to design, finance and build a 30,000-barrel-per-day (bpd) oil refinery, the first for the South American country as it becomes a force in crude oil production.',
#    'url': 'https://www.reuters.com/business/energy/guyana-opens-tender-its-first-oil-refinery-2022-10-17/',
#    'urlToImage': 'https://www.reuters.com/resizer/g21-6R2_TyjSz7XCUTD7r29e5xw=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/RSJOVGA6TJKBDJPWLCWTUMS7AM.jpg',
#    'publishedAt': '2022-10-17T14:45:00Z',
#    'content': 'Oct 17 (Reuters) - Guyana has called for proposals to design, finance and build a 30,000-barrel-per-day (bpd) oil refinery, the first for the South American country as it becomes a force in crude oil… [+1565 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Malaysia end-Sept palm oil stocks up 10.54% m/m at 2.32 mln t - MPOB - Reuters',
#    'description': "Malaysia's palm oil stocks at the end of September rose 10.54% from the month before to 2.32 million tonnes, data from the Malaysian Palm Oil Board (MPOB) showed on Tuesday.",
#    'url': 'https://www.reuters.com/business/energy/malaysia-end-sept-palm-oil-stocks-up-1054-mm-232-mln-t-mpob-2022-10-11/',
#    'urlToImage': 'https://www.reuters.com/resizer/U2w3bcWnhXgNtsJC1xdaEBe4DYU=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/QWZWEFVJNNKGZALHH5H5NBY66U.jpg',
#    'publishedAt': '2022-10-11T04:49:00Z',
#    'content': "Oct, 11 (Reuters) - Malaysia's palm oil stocks at the end of September rose 10.54% from the month before to 2.32 million tonnes, data from the Malaysian Palm Oil Board (MPOB) showed on Tuesday.\r\nCrud… [+541 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Oil prices rise after OPEC+ agrees to slash crude output - Reuters.com',
#    'description': 'Oil prices edged up in early Asian trade on Thursday after OPEC+ agreed to further tighten global crude supply with a deal to slash oil production by about 2 million barrel per day.',
#    'url': 'https://www.reuters.com/business/energy/oil-prices-rise-after-opec-agrees-slash-crude-output-2022-10-06/',
#    'urlToImage': 'https://www.reuters.com/resizer/FUSdS-edByu3sgHHMywyxin6Q5o=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/MWBP3RIWX5MTVMQQ6WASJSAXC4.jpg',
#    'publishedAt': '2022-10-06T00:46:00Z',
#    'content': 'Oct 6 (Reuters) - Oil prices edged up in early Asian trade on Thursday after OPEC+ agreed to further tighten global crude supply with a deal to slash oil production by about 2 million barrel per day.… [+1569 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Sakhalin 1 important for Japan oil procurement, trade minister says - Reuters',
#    'description': 'Japanese Trade Minister Yasutoshi Nishimura said on Sunday that the Sakhalin 1 oil and gas project in Russia is very important for Tokyo to ensure its diversified crude oil procurement.',
#    'url': 'https://www.reuters.com/business/energy/sakhalin-1-important-japan-oil-procurement-japan-trade-minister-2022-10-09/',
#    'urlToImage': 'https://www.reuters.com/resizer/TP3lrWZ1OtmbH0LzcnbZUnuv7NE=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/72RGBL7EFVKNVNVFJRG4BJFS34.jpg',
#    'publishedAt': '2022-10-09T00:44:00Z',
#    'content': 'TOKYO, Oct 9 (Reuters) - Japanese Trade Minister Yasutoshi Nishimura said on Sunday that the Sakhalin 1 oil and gas project in Russia is very important for Tokyo to ensure its diversified crude oil p… [+661 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'ADNOC invites banks to pitch for IPO of logistics unit- sources - Reuters',
#    'description': 'State oil firm Abu Dhabi National Oil Company (ADNOC) has invited banks to pitch for roles in an initial public offering of its marine services and logistics unit, two sources with knowledge of the matter said on Thursday.',
#    'url': 'https://www.reuters.com/markets/europe/adnoc-invites-banks-pitch-ipo-logistics-unit-sources-2022-10-20/',
#    'urlToImage': 'https://www.reuters.com/resizer/83a2TCkmMzyzhFIloSdxb3LLves=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/N7QCO6PFBVPNBCD6V3USQWODNE.jpg',
#    'publishedAt': '2022-10-20T14:58:00Z',
#    'content': 'LONDON, Oct 20 (Reuters) - State oil firm Abu Dhabi National Oil Company (ADNOC) has invited banks to pitch for roles in an initial public offering of its marine services and logistics unit, two sour… [+2644 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Philippines hopes Cadlao oil redevelopment will revitalise upstream sector - Reuters',
#    'description': 'The Philippines is seeking to revive its moribund upstream oil industry with the redevelopment of an oil field that last produced in the early 1990s, as it hopes to wean itself off fuel imports, energy officials said on Wednesday.',
#    'url': 'https://www.reuters.com/business/energy/philippines-hopes-cadlao-oil-redevelopment-will-revitalise-upstream-sector-2022-10-12/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=116',
#    'publishedAt': '2022-10-12T07:18:00Z',
#    'content': 'MANILA, Oct 12 (Reuters) - The Philippines is seeking to revive its moribund upstream oil industry with the redevelopment of an oil field that last produced in the early 1990s, as it hopes to wean it… [+1979 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Nigerian oil export terminal had theft line into sea for 9 years - Reuters',
#    'description': 'Officials in Nigeria discovered an illegal connection line from one of its major oil export terminals into the sea that had been operating undetected for nine years, the head of state oil company NNPC LTD said.',
#    'url': 'https://www.reuters.com/world/africa/nigerian-oil-export-terminal-had-theft-line-into-sea-9-years-2022-10-05/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=114',
#    'publishedAt': '2022-10-05T17:35:00Z',
#    'content': 'ABUJA, Oct 5 (Reuters) - Officials in Nigeria discovered an illegal connection line from one of its major oil export terminals into the sea that had been operating undetected for nine years, the head… [+1833 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Acting Kuwaiti oil minister: OPEC+ works to serve the global economy not threaten it - Reuters',
#    'description': "Kuwait's acting oil minister Mohammed Al-Fares said on Wednesday that the OPEC+ decision to cut production by 2 million barrels per day will have positive ramifications on the oil markets, the state news agency reported.",
#    'url': 'https://www.reuters.com/business/energy/acting-kuwaiti-oil-minister-opec-works-serve-global-economy-not-threaten-it-2022-10-05/',
#    'urlToImage': 'https://www.reuters.com/resizer/pY9mGp-Vj-zk_x_khYhnqsTl7PQ=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/QDJFEXLFABJJVB57TTO6I47M5I.jpg',
#    'publishedAt': '2022-10-05T21:25:00Z',
#    'content': "CAIRO, Oct 5 (Reuters) - Kuwait's acting oil minister Mohammed Al-Fares said on Wednesday that the OPEC+ decision to cut production by 2 million barrels per day will have positive ramifications on th… [+465 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Oil takes a breather, eases off 5-week highs - Reuters.com',
#    'description': 'Oil prices slipped on Monday, easing off five-week highs, as the market took profits following strong gains last week on expectations of tighter supplies following OPEC+ cuts and ahead of the European Union embargo on Russian oil.',
#    'url': 'https://www.reuters.com/business/energy/oil-takes-breather-eases-off-5-week-highs-2022-10-10/',
#    'urlToImage': 'https://www.reuters.com/resizer/pGJX1nKNdECZMw7OqF3vnhUa89Q=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/I7J2V4ICY5J5TLXFKETAKS6HCI.jpg',
#    'publishedAt': '2022-10-10T02:00:36Z',
#    'content': 'SINGAPORE, Oct 10 (Reuters) - Oil prices slipped on Monday, easing off five-week highs, as the market took profits following strong gains last week on expectations of tighter supplies following OPEC+… [+2209 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'U.S. prosecutors charge five Russians, PDVSA traders with sanctions evasion - Reuters.com',
#    'description': 'U.S. prosecutors on Wednesday charged five Russian nationals and two traders for Venezuelan state oil company Petroleos de Venezuela for sanctions evasion and other charges over a scheme to ship Venezuelan oil to Russian and Chinese buyers.',
#    'url': 'https://www.reuters.com/world/us-prosecutors-charge-five-russians-pdvsa-traders-with-sanctions-evasion-2022-10-19/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=116',
#    'publishedAt': '2022-10-19T18:39:00Z',
#    'content': 'NEW YORK, Oct 19 (Reuters) - U.S. prosecutors on Wednesday charged five Russian nationals and two traders for Venezuelan state oil company Petroleos de Venezuela for sanctions evasion and other charg… [+891 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Hungary, Serbia agree to build pipeline to ship Russian oil to Serbia - Hungarian govt - Reuters',
#    'description': 'Hungary and Serbia have agreed to build an oil pipeline that would allow Serbia to be supplied with Russian Urals crude via the Druzhba oil pipeline, the Hungarian government spokesman said on Monday.',
#    'url': 'https://www.reuters.com/business/energy/hungary-serbia-agree-build-pipeline-ship-russian-oil-serbia-hungarian-govt-2022-10-10/',
#    'urlToImage': 'https://www.reuters.com/resizer/_eRcRf4141oaUPCcUc8zgJHohdg=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/MS462UBXYJJANMBNREVZIEO23Q.jpg',
#    'publishedAt': '2022-10-10T08:30:00Z',
#    'content': 'BUDAPEST, Oct 10 (Reuters) - Hungary and Serbia have agreed to build an oil pipeline that would allow Serbia to be supplied with Russian Urals crude via the Druzhba oil pipeline, the Hungarian govern… [+548 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': 'Drone footage shows oil leak on Druzhba pipeline - Reuters.com',
#    'description': 'Drone footage on Wednesday (October 12) shows an oil spill in a field where the Druzhba pipeline, carrying Russian oil to Europe, leaked near its Polish hub, the Plock refinery.',
#    'url': 'https://www.reuters.com/video/watch/idOV175212102022RP1',
#    'urlToImage': 'https://static.reuters.com/resources/r/?d=20221012&i=OV175212102022RP1&r=OV175212102022RP1&t=2',
#    'publishedAt': '2022-10-12T14:19:19Z',
#    'content': 'Posted \r\nDrone footage on Wednesday (October 12) shows an oil spill in a field where the Druzhba pipeline, carrying Russian oil to Europe, leaked near its Polish hub, the Plock refinery.'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Shell investigates in Nigeria after report of nine-year oil theft - Reuters',
#    'description': 'Oil major Shell\'s <a href="https://www.reuters.com/companies/SHEL.L" target="_blank">(SHEL.L)</a> Nigerian subsidiary is investigating reports that an illegal oil tap ran for nine years on a pipeline it operates, a spokesperson said on Wednesday.',
#    'url': 'https://www.reuters.com/markets/commodities/shell-investigates-nigeria-after-report-nine-year-oil-theft-2022-10-12/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=116',
#    'publishedAt': '2022-10-12T14:59:00Z',
#    'content': "LAGOS, Oct 12 (Reuters) - Oil major Shell's (SHEL.L) Nigerian subsidiary is investigating reports that an illegal oil tap ran for nine years on a pipeline it operates, a spokesperson said on Wednesda… [+1304 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Column: Diesel's gloomy message for the global economy: Kemp - Reuters",
#    'description': 'Global shortages of middle distillates such as diesel, gas oil and heating oil are intensifying rather than easing – making it more likely a relatively severe slowdown in the business cycle will be necessary to rebalance the market:',
#    'url': 'https://www.reuters.com/markets/asia/diesels-gloomy-message-global-economy-kemp-2022-10-14/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=116',
#    'publishedAt': '2022-10-14T17:26:00Z',
#    'content': 'LONDON, Oct 14 (Reuters) - Global shortages of middle distillates such as diesel, gas oil and heating oil are intensifying rather than easing making it more likely a relatively severe slowdown in the… [+5819 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "EU emergency oil stocks still low in July after IEA's joint releases - Reuters",
#    'description': "The European Union's emergency oil stocks, including crude oil and petroleum products, recovered slightly in July after two coordinated releases drained the levels to a record low in June, the bloc's statistic office said on Tuesday.",
#    'url': 'https://www.reuters.com/business/energy/eu-emergency-oil-stocks-still-low-july-after-ieas-joint-releases-2022-10-18/',
#    'urlToImage': 'https://www.reuters.com/resizer/X1Z1CQePzWaTTVHoVIXlyawM_Wg=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/IMO2HKP3PNO37PNYEZRRPPTLQY.jpg',
#    'publishedAt': '2022-10-18T12:46:00Z',
#    'content': "Oct 18 (Reuters) - The European Union's emergency oil stocks, including crude oil and petroleum products, recovered slightly in July after two coordinated releases drained the levels to a record low … [+1771 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Hungary MOL says oil supplies via Druzhba pipeline to Hungary coming as planned - Reuters.com',
#    'description': 'Russian oil supplies via the Druzhba pipeline are coming to Hungary uninterrupted, a spokeswoman for Hungarian oil and gas group MOL said in a reply to Reuters questions on Wednesday.',
#    'url': 'https://www.reuters.com/business/energy/hungary-mol-says-oil-supplies-via-druzhba-pipeline-hungary-coming-planned-2022-10-12/',
#    'urlToImage': 'https://www.reuters.com/resizer/QKjoz0-rzrAfcKc98xhOqc5ryok=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/FL2QY35X5ZKI5JX6XWK6BWOM2Y.jpg',
#    'publishedAt': '2022-10-12T08:20:00Z',
#    'content': 'BUDAPEST, Oct 12 (Reuters) - Russian oil supplies via the Druzhba pipeline are coming to Hungary uninterrupted, a spokeswoman for Hungarian oil and gas group MOL said in a reply to Reuters questions … [+510 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Oil bounces higher as U.S. dollar's strength eases - Reuters",
#    'description': "Oil prices rose in thin trade in early Asian hours on Monday as the U.S. dollar's strength eased while investors awaited data from China to gauge demand at the world's top crude oil importer.",
#    'url': 'https://www.reuters.com/business/energy/oil-bounces-higher-us-dollars-strength-eases-2022-10-17/',
#    'urlToImage': 'https://www.reuters.com/resizer/serK2l_ewKfVar50EnTMYjw9quo=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/ZQ6YKIXTCVKLBAKZIMA3P4DV5Q.jpg',
#    'publishedAt': '2022-10-17T00:58:32Z',
#    'content': "SINGAPORE, Oct 17 (Reuters) - Oil prices rose in thin trade in early Asian hours on Monday as the U.S. dollar's strength eased while investors awaited data from China to gauge demand at the world's t… [+2362 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'India offers 42 hydrocarbon blocks in latest auction - Reuters',
#    'description': "India is offering 26 oil and gas blocks and 16 coal bed methane blocks in its latest exploration licensing round, according to the country's upstream regulator, as the world's third largest oil consumer seeks to boost local output.",
#    'url': 'https://www.reuters.com/business/energy/india-offers-42-hydrocarbon-blocks-latest-auction-2022-10-11/',
#    'urlToImage': 'https://www.reuters.com/resizer/y19Zhh_iIzU1pWnrQATn3O7a8-I=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/6E72EZ67F5KN3B2VMQAKD6ZP5I.jpg',
#    'publishedAt': '2022-10-11T10:58:00Z',
#    'content': "NEW DELHI, Oct 11 (Reuters) - India is offering 26 oil and gas blocks and 16 coal bed methane blocks in its latest exploration licensing round, according to the country's upstream regulator, as the w… [+1435 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Indian minister urges OPEC+ to consider impact on consumers at Dec meeting - Reuters',
#    'description': "India's oil minister on Monday urged the OPEC+ alliance of oil producers to bear in mind the impact of their upcoming decision, expected on Dec. 4, on consumers as inflation soars across the world.",
#    'url': 'https://www.reuters.com/business/energy/indian-minister-urges-opec-consider-impact-consumers-dec-meeting-2022-10-31/',
#    'urlToImage': 'https://www.reuters.com/resizer/r9Dcs_AM8RF8jkdcDtuJnPWkY-I=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/A5JBJ6JQLVKCHHN6ENNPVQMXXY.jpg',
#    'publishedAt': '2022-10-31T11:19:00Z',
#    'content': "ABU DHABI, Oct 31 (Reuters) - India's oil minister on Monday urged the OPEC+ alliance of oil producers to bear in mind the impact of their upcoming decision, expected on Dec. 4, on consumers as infla… [+2071 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Ecuador's state oil company agrees to spot sale with PetroChina - Reuters",
#    'description': "Ecuador's state-owned oil company said on Friday it has agreed a new spot sale for 720,000 barrels of Oriente crude to Chinese oil company Petrochina International Co Ltd.",
#    'url': 'https://www.reuters.com/markets/commodities/ecuadors-state-oil-company-agrees-spot-sale-with-petrochina-2022-10-28/',
#    'urlToImage': 'https://www.reuters.com/resizer/ENzPDvUYdjqqQYQhtNHqfjcRe_Q=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/S5KNM6SQ25MRZKMY2BEDHZDBVU.jpg',
#    'publishedAt': '2022-10-28T20:48:00Z',
#    'content': "Oct 28 (Reuters) - Ecuador's state-owned oil company said on Friday it has agreed a new spot sale for 720,000 barrels of Oriente crude to Chinese oil company Petrochina International Co Ltd.\r\nThe cru… [+927 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'India state retailers to marginally cut petrol, diesel prices from Tuesday - Reuters India',
#    'description': 'India\'s top fuel retailer Indian Oil Corp <a href="https://www.reuters.com/companies/IOC.NS" target="_blank">(IOC.NS)</a> will marginally cut petrol and diesel prices from Tuesday, according to a notification sent to dealers, reflecting a decline in global oi…',
#    'url': 'https://www.reuters.com/world/india/india-state-retailers-marginally-cut-petrol-diesel-prices-tuesday-2022-10-31/',
#    'urlToImage': 'https://www.reuters.com/resizer/UVU78L00bpbFHxEG4xtn3Lnx4AM=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/XQDOARB3MVPCZJ6R4FUF4WSKUQ.jpg',
#    'publishedAt': '2022-10-31T18:12:00Z',
#    'content': "NEW DELHI, Oct 31 (Reuters) - India's top fuel retailer Indian Oil Corp (IOC.NS) will marginally cut petrol and diesel prices from Tuesday, according to a notification sent to dealers, reflecting a d… [+828 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Oil climbs 3% as dollar slips and EU ban looms - Reuters',
#    'description': "Oil rose by more than 3% on Friday as the dollar eased, with an EU ban on Russian oil looming large and investors weighing the prospects for an easing of China's COVID curbs.",
#    'url': 'https://www.reuters.com/business/energy/oil-climbs-3-dollar-slips-eu-ban-looms-2022-11-04/',
#    'urlToImage': 'https://www.reuters.com/resizer/cx4EZooTZicLAg125CDEhk2tKEE=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/INFZUADJ6JNNHLZQNM3XOQR3TU.jpg',
#    'publishedAt': '2022-11-04T12:19:00Z',
#    'content': "LONDON, Nov 4 (Reuters) - Oil rose by more than 3% on Friday as the dollar eased, with an EU ban on Russian oil looming large and investors weighing the prospects for an easing of China's COVID curbs… [+2605 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Russia ships half its Oct 1-20 seaborne Urals oil exports to Asia ahead of EU embargo - Reuters.com',
#    'description': "Russia ramped up seaborne Urals oil exports to Asia to 50% of the total over the Oct. 1-20 period ahead of a December EU embargo on the state's oil and products, according to traders and Refinitiv Eikon data.",
#    'url': 'https://www.reuters.com/markets/commodities/russia-ships-half-its-oct-1-20-seaborne-urals-oil-exports-asia-ahead-eu-embargo-2022-10-28/',
#    'urlToImage': 'https://www.reuters.com/resizer/mqiXnYF2AMhNBkmajyN47KlUiJA=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/CXATUZVUKNKDFF5IPZ7LJXMY7U.jpg',
#    'publishedAt': '2022-10-28T17:24:00Z',
#    'content': "MOSCOW, Oct 28 (Reuters) - Russia ramped up seaborne Urals oil exports to Asia to 50% of the total over the Oct. 1-20 period ahead of a December EU embargo on the state's oil and products, according … [+2000 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Oil prices edge lower as China COVID-19 woes dampen demand - Reuters',
#    'description': "Oil prices inched lower on Tuesday, extending losses of 1% from the previous session as more extensive COVID-19 curbs in China increased fears of slowing fuel demand in the world's second-largest oil consumer.",
#    'url': 'https://www.reuters.com/markets/commodities/oil-prices-edge-lower-china-covid-19-woes-dampen-demand-2022-11-01/',
#    'urlToImage': 'https://www.reuters.com/resizer/oaZIe9swBI6W8QwjKBANaiXU5Wk=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/WXEZJNQ7OJP4RJYQ532R4HL3CM.jpg',
#    'publishedAt': '2022-11-01T01:39:40Z',
#    'content': 'SINGAPORE, Nov 1 (Reuters) - Oil prices inched lower on Tuesday, extending losses of 1% from the previous session as more extensive COVID-19 curbs in China increased fears of slowing fuel demand in t… [+2391 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "China's Addax exits from four Nigerian oil blocks, NNPC says - Reuters.com",
#    'description': "Nigeria's NNPC Ltd said on Tuesday Sinopec's Addax Petroleum Development (Nigeria) Ltd had exited from its four major oil mining blocks in Nigeria and transferred them to the state-owned oil company.",
#    'url': 'https://www.reuters.com/markets/commodities/chinas-addax-exits-four-nigerian-oil-blocks-nnpc-says-2022-11-01/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=118',
#    'publishedAt': '2022-11-01T18:10:22Z',
#    'content': "LAGOS, Nov 1 (Reuters) - Nigeria's NNPC Ltd said on Tuesday Sinopec's Addax Petroleum Development (Nigeria) Ltd had exited from its four major oil mining blocks in Nigeria and transferred them to the… [+1134 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'United Arab Emirates indexes track crude prices higher - Reuters',
#    'description': "Stock markets in United Arab Emirates closed higher on Friday, after oil climbed on supply concerns fuelled by Europe's upcoming embargo on Russian oil and decline in U.S. crude stockpiles.",
#    'url': 'https://www.reuters.com/markets/united-arab-emirates-indexes-track-crude-prices-higher-2022-11-04/',
# ...
#    'urlToImage': 'https://www.reuters.com/resizer/zDRWOFxwjRB6L3_t8jkFiO5Lr2Y=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/Q5A6ZA7JG5LY7N32NYQLUPBKSU.jpg',
#    'publishedAt': '2022-10-13T10:52:00Z',
#    'content': 'WARSAW, Oct 13 (Reuters) - Repairs to a pipeline carrying Russian oil to Germany have begun and Poland does not think the incident was sabotage, the top Polish energy security official told Reuters o… [+1273 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Somalia signs oil exploration agreement for seven blocks - Reuters',
#    'description': 'Somalia has signed a petroleum exploration agreement for seven offshore blocks with United States-based Coastline Exploration, the company said in a statement on Friday.',
#    'url': 'https://www.reuters.com/business/energy/somalia-signs-oil-exploration-agreement-seven-blocks-2022-10-21/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=116',
#    'publishedAt': '2022-10-21T09:49:00Z',
#    'content': 'MOGADISHU, Oct 21 (Reuters) - Somalia has signed a petroleum exploration agreement for seven offshore blocks with United States-based Coastline Exploration, the company said in a statement on Friday.… [+1041 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': "U.S. calls OPEC+ move to cut oil output 'shortsighted' - Reuters",
#    'description': 'OPEC+ agreed to steep oil production cuts on Wednesday, curbing supply in an already tight market and causing one of its biggest clashes with the West as the Biden administration called the surprise decision shortsighted. This report produced by Chris Dignam.',
#    'url': 'https://www.reuters.com/video/watch/idOV023405102022RP1',
#    'urlToImage': 'https://static.reuters.com/resources/r/?d=20221005&i=OV023405102022RP1&r=OV023405102022RP1&t=2',
#    'publishedAt': '2022-10-05T20:54:11Z',
#    'content': 'Posted \r\nOPEC+ agreed to steep oil production cuts on Wednesday, curbing supply in an already tight market and causing one of its biggest clashes with the West as the Biden administration called the … [+68 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Most major bourses track Asian shares, oil prices lower - Reuters',
#    'description': 'Most major stock markets in the Gulf fell in early trade on Monday, tracking losses in Asian shares and oil prices, although the Saudi index was on track to snap a three-day losing streak.',
#    'url': 'https://www.reuters.com/world/middle-east/most-major-bourses-track-asian-shares-oil-prices-lower-2022-10-10/',
#    'urlToImage': 'https://www.reuters.com/resizer/mfIznU-wcgNsLm8wVXiDv68gni8=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/GV6NJ4N6ANM2BHU5EL2PEY5AEM.jpg',
#    'publishedAt': '2022-10-10T08:25:00Z',
#    'content': 'Oct 10 (Reuters) - Most major stock markets in the Gulf fell in early trade on Monday, tracking losses in Asian shares and oil prices, although the Saudi index was on track to snap a three-day losing… [+1848 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Saudi stocks gain on rising oil prices; Qatar falls - Reuters',
#    'description': "Saudi Arabia's stock market rose in early trade on Thursday amid rising oil prices, while Qatari shares extended losses from the previous session.",
#    'url': 'https://www.reuters.com/markets/asia/saudi-stocks-gain-rising-oil-prices-qatar-falls-2022-10-20/',
#    'urlToImage': 'https://www.reuters.com/resizer/TQW22iHIi8ahnoaItQVNk1T2cdw=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/Y2GD4WH2AFN3JPAQLNOAUI25VE.jpg',
#    'publishedAt': '2022-10-20T08:58:00Z',
#    'content': "Oct 20 (Reuters) - Saudi Arabia's stock market rose in early trade on Thursday amid rising oil prices, while Qatari shares extended losses from the previous session.\r\nCrude oil prices, a key catalyst… [+2071 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Oil slides as U.S. crude and gasoline stocks surge - Reuters.com',
#    'description': 'Oil prices slipped in early Asian trade on Friday as U.S. crude and gasoline inventories jumped, while Saudi Arabia and Washington continued to clash over plans by OPEC+ to slash production.',
#    'url': 'https://www.reuters.com/business/energy/oil-slides-us-crude-gasoline-stocks-surge-2022-10-14/',
#    'urlToImage': 'https://www.reuters.com/resizer/-LV5nAG975FkqUbXv4lUOj1IKvs=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/5LZTAZB67FNSFCTERTAORCK2Y4.jpg',
#    'publishedAt': '2022-10-14T00:59:00Z',
#    'content': 'Oct 14 (Reuters) - Oil prices slipped in early Asian trade on Friday as U.S. crude and gasoline inventories jumped, while Saudi Arabia and Washington continued to clash over plans by OPEC+ to slash p… [+1773 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Gulf bourses track global shares, oil prices lower - Reuters',
#    'description': 'Stock markets in the Gulf fell on Monday, tracking global shares and oil prices lower, with the Saudi index extending losses for a third session.',
#    'url': 'https://www.reuters.com/world/middle-east/gulf-bourses-track-global-shares-oil-prices-lower-2022-10-10/',
#    'urlToImage': 'https://www.reuters.com/resizer/mfIznU-wcgNsLm8wVXiDv68gni8=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/GV6NJ4N6ANM2BHU5EL2PEY5AEM.jpg',
#    'publishedAt': '2022-10-10T13:43:00Z',
#    'content': 'Oct 10 (Reuters) - Stock markets in the Gulf fell on Monday, tracking global shares and oil prices lower, with the Saudi index extending losses for a third session.\r\nGlobal shares dropped after Russi… [+2264 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Portugal's Galp quarterly profit up 16% on higher oil prices, better margins - Reuters",
#    'description': 'Portuguese oil and gas company Galp Energia <a href="https://www.reuters.com/companies/GALP.LS" target="_blank">(GALP.LS)</a> reported a 16% increase in adjusted third-quarter profit on Monday, thanks to soaring oil prices and a near-doubling of its refining …',
#    'url': 'https://www.reuters.com/business/energy/portugals-galp-quarterly-profit-up-16-higher-oil-prices-better-margins-2022-10-24/',
#    'urlToImage': 'https://www.reuters.com/resizer/9DeUgvaS1Mxv_tHrWfbagv23CuQ=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/6UFJKHPE5ZILBKBR6EMPDTMV6I.jpg',
#    'publishedAt': '2022-10-24T06:03:25Z',
#    'content': 'LISBON, Oct 24 (Reuters) - Portuguese oil and gas company Galp Energia (GALP.LS) reported a 16% increase in adjusted third-quarter profit on Monday, thanks to soaring oil prices and a near-doubling o… [+1579 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Mexico's Pemex gets green light for deepwater gas field's revamped plan - Reuters",
#    'description': 'Mexico\'s oil regulator approved on Monday a revamped plan for developing the Lakach <a href="/business/energy/pemex-deepwater-gas-project-draws-rebuke-mexicos-regulator-2022-09-13/">deepwater natural gas project</a>, presented by state oil company Pemex, in t…',
#    'url': 'https://www.reuters.com/business/energy/mexicos-pemex-gets-green-light-deepwater-gas-fields-revamped-plan-2022-10-31/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=118',
#    'publishedAt': '2022-10-31T21:36:00Z',
#    'content': "MEXICO CITY, Oct 31 (Reuters) - Mexico's oil regulator approved on Monday a revamped plan for developing the Lakach deepwater natural gas project, presented by state oil company Pemex, in the first p… [+1026 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Reforms, diversification drive key to Gulf prospects for future growth, IMF says - Reuters',
#    'description': 'Gulf Arab oil exporters are expected on average to put away about 33% of their oil revenues over 2022-26, leading to an improvement in the overall fiscal balance, the International Monetary Fund said on Monday, stressing the need to resist temptations to reve…',
#    'url': 'https://www.reuters.com/business/finance/reforms-diversification-drive-key-gulf-prospects-future-growth-imf-says-2022-10-31/',
#    'urlToImage': 'https://www.reuters.com/resizer/Q2PLFjPM7YSYVAn7nYOx3uGkxp8=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/HAY4RP72CBIS5ISRZSN52FE4GM.jpg',
#    'publishedAt': '2022-10-31T05:38:00Z',
#    'content': 'DUBAI, Oct 31 (Reuters) - Gulf Arab oil exporters are expected on average to put away about 33% of their oil revenues over 2022-26, leading to an improvement in the overall fiscal balance, the Intern… [+2251 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Saudi forum set to draw U.S. business leaders despite tensions - Reuters',
#    'description': 'A public <a href="/business/energy/saudi-oil-power-play-bruises-us-ties-wont-break-them-2022-10-13/">spat</a> between the United States and Saudi Arabia will not deter top Wall Street executives and U.S. business leaders from a flagship investment event start…',
#    'url': 'https://www.reuters.com/business/saudi-forum-set-draw-us-business-leaders-despite-tensions-2022-10-23/',
#    'urlToImage': 'https://www.reuters.com/resizer/Q2PLFjPM7YSYVAn7nYOx3uGkxp8=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/HAY4RP72CBIS5ISRZSN52FE4GM.jpg',
#    'publishedAt': '2022-10-23T08:45:00Z',
#    'content': 'DUBAI, Oct 23 (Reuters) - A public spat between the United States and Saudi Arabia will not deter top Wall Street executives and U.S. business leaders from a flagship investment event starting on Tue… [+4582 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'UAE ADNOC Chief says world needs maximum energy, minimum emissions - Reuters',
#    'description': 'Abu Dhabi National Oil Co (ADNOC) Chief Executive Sultan al-Jaber said on Monday that zeroing out hydrocarbon investment due to natural decline could lead to a loss of 5 million barrels of oil per day a year from current supplies.',
#    'url': 'https://www.reuters.com/business/energy/uae-adnoc-chief-says-world-needs-maximum-energy-minimum-emissions-2022-10-31/',
#    'urlToImage': 'https://www.reuters.com/resizer/pbXQ2RL2siETjGJ1ATEuPWGkN28=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/XBBEFNYSBZLB7MGR5T5XKCZ2U4.jpg',
#    'publishedAt': '2022-10-31T06:38:00Z',
#    'content': 'ABU DHABI, Oct 31 (Reuters) - Abu Dhabi National Oil Co (ADNOC) Chief Executive Sultan al-Jaber said on Monday that zeroing out hydrocarbon investment due to natural decline could lead to a loss of 5… [+795 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Exxon Mobil makes two new discoveries in Guyana - Reuters',
#    'description': 'Exxon Mobil Corp <a href="https://www.reuters.com/companies/XOM.N" target="_blank">(XOM.N)</a> has made two new discoveries at the Sailfin-1 and Yarrow-1 wells in the Stabroek block offshore Guyana, the oil major said on Wednesday, adding more barrels to one …',
#    'url': 'https://www.reuters.com/business/energy/exxon-mobil-makes-two-new-discoveries-guyana-2022-10-26/',
#    'urlToImage': 'https://www.reuters.com/resizer/ICiUJkwjcUp7UuGAXs8mJIq47To=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/HZC6ZJCTIJI2DOMDFBWASFIYBM.jpg',
#    'publishedAt': '2022-10-26T11:19:00Z',
#    'content': 'Oct 26 (Reuters) - Exxon Mobil Corp (XOM.N) has made two new discoveries at the Sailfin-1 and Yarrow-1 wells in the Stabroek block offshore Guyana, the oil major said on Wednesday, adding more barrel… [+1136 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'German Jan-Aug oil imports up 11.4%, bill nearly doubles - Reuters',
#    'description': 'German crude oil import volumes rose 11.4% in the first eight months of 2022 on a year-on-year basis as the economy recovered from the COVID-19 pandemic, while the bill nearly doubled due to <a href="/markets/commodities/oil-prices-edge-lower-china-covid-19-w…',
#    'url': 'https://www.reuters.com/business/energy/german-jan-aug-oil-imports-up-114-bill-nearly-doubles-2022-11-01/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=118',
#    'publishedAt': '2022-11-01T16:46:00Z',
#    'content': 'FRANKFURT, Nov 1 (Reuters) - German crude oil import volumes rose 11.4% in the first eight months of 2022 on a year-on-year basis as the economy recovered from the COVID-19 pandemic, while the bill n… [+1684 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Suncor Fort Hills deal hints at new strategy for Canada oil sands mine replacement - Reuters.com',
#    'description': 'Suncor Energy\'s <a href="https://www.reuters.com/companies/SU.TO" target="_blank">(SU.TO)</a> acquisition of a larger stake in the Fort Hills oil sands project is a sign that Canada\'s second-largest oil company is looking for alternatives to extending the lif…',
#    'url': 'https://www.reuters.com/business/energy/suncor-fort-hills-deal-hints-new-strategy-canada-oil-sands-mine-replacement-2022-11-02/',
#    'urlToImage': 'https://www.reuters.com/resizer/Zfj3qvWXAwDmwmUT0DnXXSTiWT0=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/HIDAPF3U6VLI5IQLQ6PHG7XTFU.jpg',
#    'publishedAt': '2022-11-02T10:06:00Z',
#    'content': "Nov 2 (Reuters) - Suncor Energy's (SU.TO) acquisition of a larger stake in the Fort Hills oil sands project is a sign that Canada's second-largest oil company is looking for alternatives to extending… [+3366 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'U.S. crude and fuel stockpiles down last week - EIA - Reuters',
#    'description': 'U.S. crude oil, gasoline and distillate inventories fell last week, the Energy Information Administration said on Wednesday.',
#    'url': 'https://www.reuters.com/markets/commodities/us-crude-fuel-stockpiles-down-last-week-eia-2022-10-05/',
#    'urlToImage': 'https://www.reuters.com/resizer/inCiljPy7RZv-PZN5LaqvFhi3qs=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/ZJNXNE45VBKSPJRYSTJZGOISOY.jpg',
#    'publishedAt': '2022-10-05T15:04:00Z',
#    'content': 'Oct 5 (Reuters) - U.S. crude oil, gasoline and distillate inventories fell last week, the Energy Information Administration said on Wednesday.\r\nCrude inventories (USOILC=ECI) fell by 1.4 million barr… [+1600 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Munich Re tightens oil and gas policies - Reuters',
#    'description': "Munich Re , the world's largest reinsurer, on Thursday announced stricter policies for investing in and underwriting oil and gas projects, drawing praise from environmental activists.",
#    'url': 'https://www.reuters.com/business/sustainable-business/munich-re-tightens-oil-gas-policies-2022-10-06/',
#    'urlToImage': 'https://www.reuters.com/resizer/T29WM60qpTYpFf5meMOP7kmSUM8=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/E4PVWE4SM5KNXGOJTDC2EMFATY.jpg',
#    'publishedAt': '2022-10-06T13:08:00Z',
#    'content': "FRANKFURT, Oct 6 (Reuters) - Munich Re , the world's largest reinsurer, on Thursday announced stricter policies for investing in and underwriting oil and gas projects, drawing praise from environment… [+1375 chars]"}]}

# %%
a = api.get_everything(q="minyak")

# %%
a["articles"][10]["url"]
# Out:
# 'https://freecabinporn.com/arti-mimpi-tisu/'

# %%
from full_fred.fred import Fred
fred = Fred(api_key_file="../key.txt")
fred.env_api_key_found()
# Out:
# True

# %%
fred.get_series_df('GDPPOT')
fred.series_stack['get_series_df']
# Out:
# {'realtime_start': '2022-11-06',
#  'realtime_end': '2022-11-06',
#  'observation_start': '1600-01-01',
#  'observation_end': '9999-12-31',
#  'units': 'lin',
#  'output_type': 1,
#  'file_type': 'json',
#  'order_by': 'observation_date',
#  'sort_order': 'asc',
#  'count': 336,
#  'offset': 0,
#  'limit': 100000,
#  'series_id': 'GDPPOT',
#  'df':     realtime_start realtime_end        date               value
#  0       2022-11-06   2022-11-06  1949-01-01  2104.0506049138817
#  1       2022-11-06   2022-11-06  1949-04-01  2131.6486926425077
#  2       2022-11-06   2022-11-06  1949-07-01   2160.479542925909
#  3       2022-11-06   2022-11-06  1949-10-01   2188.028985512548
#  4       2022-11-06   2022-11-06  1950-01-01    2217.26007703257
#  ..             ...          ...         ...                 ...
#  331     2022-11-06   2022-11-06  2031-10-01            23876.74
#  332     2022-11-06   2022-11-06  2032-01-01            23978.93
#  333     2022-11-06   2022-11-06  2032-04-01            24081.32
#  334     2022-11-06   2022-11-06  2032-07-01            24183.71
#  335     2022-11-06   2022-11-06  2032-10-01            24286.07
#
#  [336 rows x 4 columns]}

# %%
fred.get_child_categories(0)
# Out:
# {'categories': [{'id': 32991,
#    'name': 'Money, Banking, & Finance',
#    'parent_id': 0},
#   {'id': 10,
#    'name': 'Population, Employment, & Labor Markets',
#    'parent_id': 0},
#   {'id': 32992, 'name': 'National Accounts', 'parent_id': 0},
#   {'id': 1, 'name': 'Production & Business Activity', 'parent_id': 0},
#   {'id': 32455, 'name': 'Prices', 'parent_id': 0},
#   {'id': 32263, 'name': 'International Data', 'parent_id': 0},
#   {'id': 3008, 'name': 'U.S. Regional Data', 'parent_id': 0},
#   {'id': 33060, 'name': 'Academic Data', 'parent_id': 0}]}

# %%
fred.get_all_sources()
# Out:
# {'realtime_start': '2022-11-06',
#  'realtime_end': '2022-11-06',
#  'order_by': 'source_id',
#  'sort_order': 'asc',
#  'count': 110,
#  'offset': 0,
#  'limit': 1000,
#  'sources': [{'id': 1,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Board of Governors of the Federal Reserve System (US)',
#    'link': 'http://www.federalreserve.gov/'},
#   {'id': 3,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Federal Reserve Bank of Philadelphia',
#    'link': 'https://www.philadelphiafed.org/'},
#   {'id': 4,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Federal Reserve Bank of St. Louis',
#    'link': 'http://www.stlouisfed.org/'},
#   {'id': 6,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Federal Financial Institutions Examination Council (US)',
#    'link': 'http://www.ffiec.gov/'},
#   {'id': 11,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Dow Jones & Company',
#    'link': 'http://www.dowjones.com'},
#   {'id': 14,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'University of Michigan',
#    'link': 'https://www.umich.edu/'},
#   {'id': 15,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Council of Economic Advisers (US)',
#    'link': 'https://www.whitehouse.gov/cea/'},
#   {'id': 16,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'U.S. Office of Management and Budget',
#    'link': 'https://www.whitehouse.gov/omb/'},
#   {'id': 17,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'U.S. Congressional Budget Office',
#    'link': 'http://www.cbo.gov/'},
#   {'id': 18,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'U.S. Bureau of Economic Analysis',
#    'link': 'http://www.bea.gov/'},
#   {'id': 19,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'U.S. Census Bureau',
#    'link': 'http://www.census.gov/'},
#   {'id': 21,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'U.S. Department of Housing and Urban Development',
#    'link': 'http://www.hud.gov/'},
#   {'id': 22,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'U.S. Bureau of Labor Statistics',
#    'link': 'https://www.bls.gov/'},
#   {'id': 23,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'U.S. Department of the Treasury. Fiscal Service',
#    'link': 'https://fiscaldata.treasury.gov/'},
#   {'id': 26,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Haver Analytics',
#    'link': 'http://www.haver.com/'},
#   {'id': 31,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Reserve Bank of Australia',
#    'link': 'http://www.rba.gov.au/'},
#   {'id': 32,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Deutsche Bundesbank',
#    'link': 'http://www.bundesbank.de'},
#   {'id': 33,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Bank of Italy',
#    'link': 'http://www.bancaditalia.it/homepage/index.html?com.dotmarketing.htmlpage.language=1',
#    'notes': "Banca d'Italia"},
#   {'id': 34,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Swiss National Bank',
#    'link': 'http://www.snb.ch/'},
#   {'id': 35,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Central Bank of the Republic of Turkey',
#    'link': 'http://www.tcmb.gov.tr/',
#    'notes': 'Türkiye Cumhuriyet Merkez Bankası'},
#   {'id': 36,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'U.S. Federal Housing Finance Agency',
#    'link': 'http://www.fhfa.gov/'},
#   {'id': 37,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Bank of Japan'},
#   {'id': 38,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Bank of Mexico',
#    'link': 'http://www.banxico.org.mx/',
#    'notes': 'Banco de México'},
#   {'id': 41,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Freddie Mac',
#    'link': 'http://www.freddiemac.com/index.html'},
#   {'id': 42,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Automatic Data Processing, Inc.',
#    'link': 'http://www.adp.com/'},
#   {'id': 44,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Wilshire Associates',
#    'link': 'http://www.wilshire.com/'},
#   {'id': 46,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Federal Reserve Bank of Kansas City',
#    'link': 'https://www.kansascityfed.org/'},
#   {'id': 47,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Chicago Board Options Exchange',
#    'link': 'http://www.cboe.com/'},
#   {'id': 48,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Organization for Economic Co-operation and Development',
#    'link': 'http://www.oecd.org/'},
#   {'id': 50,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'U.S. Employment and Training Administration',
#    'link': 'http://www.doleta.gov'},
#   {'id': 53,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'U.S. Energy Information Administration',
#    'link': 'http://www.eia.gov/'},
#   {'id': 54,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Federal Reserve Bank of Chicago',
#    'link': 'http://www.chicagofed.org'},
#   {'id': 55,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'National Bureau of Economic Research',
#    'link': 'http://www.nber.org/'},
#   {'id': 57,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'World Bank',
#    'link': 'http://www.worldbank.org/'},
#   {'id': 59,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'National Association of Realtors',
#    'link': 'http://www.realtor.org'},
#   {'id': 60,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'International Monetary Fund',
#    'link': 'https://www.imf.org/external/index.htm',
#    'notes': 'The International Monetary Fund (IMF) is an organization of 187 countries, working to foster global monetary cooperation, secure financial stability, facilitate international trade, promote high employment and sustainable economic growth, and reduce poverty around the world.'},
#   {'id': 61,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Eurostat',
#    'link': 'http://ec.europa.eu/eurostat/about/overview'},
#   {'id': 63,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'U.S. Federal Highway Administration',
#    'link': 'http://www.fhwa.dot.gov/'},
#   {'id': 66,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'University of Pennsylvania',
#    'link': 'http://www.upenn.edu/'},
#   {'id': 67,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'CredAbility Nonprofit Credit Counseling & Education',
#    'link': 'http://www.credability.org/en/homepage.aspx'},
#   {'id': 68,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Piger, Jeremy Max',
#    'link': 'http://pages.uoregon.edu/jpiger/us_recession_probs.htm'},
#   {'id': 69,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Federal Deposit Insurance Corporation',
#    'link': 'http://www.fdic.gov/'},
#   {'id': 70,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Weber, Warren E.'},
#   {'id': 71,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Dwyer, Gerald P.'},
#   {'id': 72,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Hafer, R.W.'},
#   {'id': 74,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'GB. Office for National Statistics',
#    'link': 'http://www.ons.gov.uk/ons/index.html'},
#   {'id': 75,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'JP. Cabinet Office',
#    'link': 'http://www.cao.go.jp/index-e.html',
#    'notes': 'JP. Naikakufu'},
#   {'id': 76,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Bank of England',
#    'link': 'http://www.bankofengland.co.uk/Pages/home.aspx'},
#   {'id': 77,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'European Central Bank',
#    'link': 'https://www.ecb.europa.eu/home/html/index.en.html'},
#   {'id': 78,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'University of Louisville. Logistics and Distribution Institute',
#    'link': 'http://louisville.edu/lodi'},
#   {'id': 80,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Baker, Scott R.'},
#   {'id': 81,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Cass Information Systems, Inc.',
#    'link': 'http://www.cassinfo.com/'},
#   {'id': 82,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Anderson, Richard G.',
#    'link': 'http://research.stlouisfed.org/econ/anderson/'},
#   {'id': 84,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'University of Groningen',
#    'link': 'http://www.rug.nl/'},
#   {'id': 85,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'S&P Dow Jones Indices LLC',
#    'link': 'https://us.spindices.com/'},
#   {'id': 86,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Nikkei Industry Research Institute',
#    'link': 'http://indexes.nikkei.co.jp/en/nkave/index/profile?idx=nk225'},
#   {'id': 88,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'DiCecio, Riccardo',
#    'link': 'http://research.stlouisfed.org/econ/dicecio/'},
#   {'id': 89,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Federal Reserve Bank of Dallas',
#    'link': 'http://www.dallasfed.org/'},
#   {'id': 90,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Federal Reserve Bank of Cleveland',
#    'link': 'http://www.clevelandfed.org/'},
#   {'id': 91,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Federal Reserve Bank of Atlanta',
#    'link': 'http://www.frbatlanta.org/'},
#   {'id': 92,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Federal Reserve Bank of San Francisco',
#    'link': 'http://www.frbsf.org/'},
#   {'id': 93,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Bank for International Settlements',
#    'link': 'https://www.bis.org/index.htm'},
#   {'id': 94,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'University of California, Davis',
#    'link': 'http://www.ucdavis.edu/'},
#   {'id': 96,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Federal Reserve Bank of New York',
#    'link': 'http://www.newyorkfed.org/'},
#   {'id': 97,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'NASDAQ OMX Group',
#    'link': 'https://www.nasdaq.com/'},
#   {'id': 98,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'U.S. Federal Open Market Committee'},
#   {'id': 99,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Equifax',
#    'link': 'http://www.equifax.com/home/en_us'},
#   {'id': 101,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'U.S. Bureau of Transportation Statistics',
#    'link': 'https://www.bts.gov/'},
#   {'id': 102,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Chauvet, Marcelle'},
#   {'id': 103,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Jones, Barry E.'},
#   {'id': 104,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Bloom, Nick'},
#   {'id': 105,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Davis, Stephen J.'},
#   {'id': 106,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Oklahoma State University',
#    'link': 'http://go.okstate.edu/'},
#   {'id': 114,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'U.S. Department of Labor',
#    'link': 'http://www.dol.gov'},
#   {'id': 115,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Federal Reserve Bank of Richmond',
#    'link': 'https://www.richmondfed.org/'},
#   {'id': 116,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Hamilton, James',
#    'link': 'http://econbrowser.com/recession-index'},
#   {'id': 122,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'U.S. Department of the Treasury. Internal Revenue Service',
#    'link': 'https://www.irs.gov/'},
#   {'id': 123,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'U.S. Department of the Treasury',
#    'link': 'https://www.treasury.gov'},
#   {'id': 126,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Federal Bureau of Investigation',
#    'link': 'https://ucr.fbi.gov/'},
#   {'id': 128,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Dartmouth Atlas of Healthcare',
#    'link': 'http://www.dartmouthatlas.org/',
#    'notes': 'The Dartmouth Atlas of Health Care is based at The Dartmouth Institute for Health Policy and Clinical Practice.'},
#   {'id': 129,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Moody’s',
#    'link': 'https://www.moodys.com/'},
#   {'id': 133,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'DHI Group, Inc.'},
#   {'id': 135,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Centers for Disease Control and Prevention',
#    'link': 'https://www.cdc.gov',
#    'notes': 'The CDC is one of the major operating components of the U.S. Department of Health and Human Services'},
#   {'id': 136,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'U.S. Patent and Trademark Office',
#    'link': 'http://www.uspto.gov/'},
#   {'id': 141,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Coinbase',
#    'link': 'https://www.coinbase.com/'},
#   {'id': 145,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Sahm, Claudia',
#    'link': 'https://equitablegrowth.org/people/claudia-sahm/'},
#   {'id': 146,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Davis, Lance E.'},
#   {'id': 147,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Stettler, H. Louis'},
#   {'id': 148,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Ice Data Indices, LLC',
#    'link': 'https://www.theice.com/market-data/indices'},
#   {'id': 149,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Realtor.com',
#    'link': 'https://realtor.com'},
#   {'id': 151,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Lewis, Daniel J.'},
#   {'id': 152,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Mertens, Karel'},
#   {'id': 153,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Stock, James H.'},
#   {'id': 154,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Ahir, Hites'},
#   {'id': 155,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Furceri, Davide'},
#   {'id': 156,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Anbil, Sriya',
#    'link': 'https://www.federalreserve.gov/econres/sriya-l-anbil.htm'},
#   {'id': 157,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Carlson, Mark',
#    'link': 'https://www.federalreserve.gov/econres/mark-a-carlson.htm'},
#   {'id': 158,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Hanes, Christopher',
#    'link': 'http://bingweb.binghamton.edu/~chanes/'},
#   {'id': 159,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Wheelock, David C',
#    'link': 'https://research.stlouisfed.org/econ/wheelock/sel/'},
#   {'id': 160,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Optimal Blue',
#    'link': 'https://www2.optimalblue.com/'},
#   {'id': 161,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Indeed',
#    'link': 'https://www.hiringlab.org/'},
#   {'id': 162,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Center for Financial Stability',
#    'link': 'http://www.centerforfinancialstability.org/hfs.php'},
#   {'id': 163,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Andrew Davidson & Co., Inc.',
#    'link': 'https://www.ad-co.com/'},
#   {'id': 164,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Aaronson, Daniel',
#    'link': 'https://www.chicagofed.org/people/a/aaronson-daniel'},
#   {'id': 165,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Hartley, Daniel',
#    'link': 'https://www.chicagofed.org/people/h/hartley-daniel'},
#   {'id': 166,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Mazumder, Bhashkar',
#    'link': 'https://www.chicagofed.org/people/m/mazumder-bhashkar'},
#   {'id': 167,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Zillow',
#    'link': 'https://www.zillow.com/',
#    'notes': 'As the most-visited real estate website in the United States, Zillow and its affiliates offer customers an on-demand experience for selling, buying, renting and financing with transparency and nearly seamless end-to-end service. Zillow Offers buys and sells homes directly in dozens of markets across the country, allowing sellers control over their timeline. Zillow Home Loans, our affiliate lender, provides our customers with an easy option to get pre-approved and secure financing for their next home purchase. Zillow recently launched Zillow Homes, Inc., a licensed brokerage entity, to streamline Zillow Offers transactions.\r\n\r\nZillow Group’s brands, affiliates and subsidiaries include Zillow, Zillow Offers, Zillow Premier Agent, Zillow Home Loans, Zillow Closing Services, Zillow Homes, Inc. Trulia, Out East, StreetEasy, HotPads, and ShowingTime.'},
#   {'id': 168,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'American Financial Exchange',
#    'link': 'https://ameribor.net/'},
#   {'id': 169,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Conference of State Bank Supervisors',
#    'link': 'https://www.csbs.org/',
#    'notes': 'CSBS supports state regulators in advancing the system of state financial supervision by ensuring safety, soundness and consumer protection; promoting economic growth; and fostering innovative, responsive supervision.\r\n\r\nCSBS was organized in 1902 as the National Association of Supervisors of State Banks. In 1971, the name of the organization was changed to the Conference of State Bank Supervisors to better reflect the ongoing nature of CSBS activities.\r\n\r\nFor more than 110 years, CSBS has been uniquely positioned as the only national organization dedicated to protecting and advancing the nation’s dual-banking system.'},
#   {'id': 202,
#    'realtime_start': '2022-11-06',
#    'realtime_end': '2022-11-06',
#    'name': 'Indiana University: Indiana Business Research Center',
#    'link': 'https://ibrc.kelley.iu.edu/',
#    'notes': 'Established in 1925, the Indiana Business Research Center is an integral unit in the Kelley School of Business at Indiana University.\r\n\r\nThe IBRC maintains databases on numerous topics such as income, employment, taxes, sectors of the economy, education, demographics and a host of other economic indicators for the nation, the state and local areas. In addition, the Center conducts original research to generate needed information when existing data are not available or sufficient.'}]}

# %%
fred.get_series_vintagedates('FYFSD', limit = 15)
# Out:
# {'realtime_start': '1776-07-04',
#  'realtime_end': '9999-12-31',
#  'order_by': 'vintage_date',
#  'sort_order': 'asc',
#  'count': 50,
#  'offset': 0,
#  'limit': 15,
#  'vintage_dates': ['1998-02-02',
#   '1998-10-26',
#   '1999-02-01',
#   '1999-10-25',
#   '2000-02-07',
#   '2000-10-20',
#   '2001-04-09',
#   '2001-10-24',
#   '2002-02-04',
#   '2002-10-23',
#   '2003-02-03',
#   '2003-10-15',
#   '2004-02-02',
#   '2004-10-12',
#   '2005-02-23']}
